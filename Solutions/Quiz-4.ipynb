# %% [markdown]
# # Solutions of Quiz-4

# %% [markdown]
# ### Q1 & Q2

# %% [markdown]
# **Syntax**
#
#
# def functionname( parameters ):
#
#     function body
#
#     return [expression]

# %% [markdown]
# ### Q3

# %% [markdown]
# Excepts print function every function returns some value

# %% [markdown]
# ### Q4

# %%
>>> def f(x,y):
>>>    x = x + y
>>>    y += 1   
>>>    print(x,y)

>>> f(y=2,x=1)
# Out:
# 3 3

# %% [markdown]
# ### Q5

# %%
>>> def func(message, num = 1):
>>>      print(message * num)

>>> func('Welcome')
>>> func('Viewers', 3)
# Out:
# Welcome
# ViewersViewersViewers

# %% [markdown]
# ### Q6

# %%
>>> def myfunc(text, num):
>>>     while num > 0:
>>>         print(text)
>>>     num = num - 1
>>> myfunc('Hello', 4)
# Out:
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# ...

# %% [markdown]
# ### Q7

# %%
>>> def func():
>>>    num = 3
>>>    print(num)

>>> func()
>>> num = 1
>>> print(num)
# Out:
# 3
# 1

# %% [markdown]
# ### Q8

# %% [markdown]
# **Syntax**
#
#
# def functionname( parameters ):
#
#     function body
#
#     return [expression]

# %% [markdown]
# ### Q9

# %%
>>> def printLine(text):
>>>    print(text, 'is awesome.')

>>> printLine('Python')
# Out:
# Python is awesome.

# %% [markdown]
# ### Q10

# %% [markdown]
# Function will return None
